# %% [markdown]
# ### Scraping job sites for information on Data Analysts and Data Engineers

# %%
import duckdb
from jobspy import scrape_jobs

# %%
analyst_jobs = scrape_jobs(
    site_name=["indeed","linkedin","glassdoor"],
    search_term="data analyst",
    location="United Kingdom",
    results_wanted=30, #total number of results are 30x3
    hours_old=72, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed="UK",  # only needed for indeed / glassdoor
    linkedin_fetch_description=True)
# Out:
# 2024-10-16 23:47:16,857 - JobSpy - INFO - Indeed search page: 1
# 2024-10-16 23:47:16,859 - JobSpy - INFO - LinkedIn search page: 1
# 2024-10-16 23:47:17,446 - JobSpy - INFO - Indeed finished scraping
# 2024-10-16 23:47:18,224 - JobSpy - INFO - Glassdoor search page: 1
# 2024-10-16 23:47:19,156 - JobSpy - INFO - Glassdoor finished scraping
# 2024-10-16 23:48:42,348 - JobSpy - INFO - LinkedIn search page: 2
# 2024-10-16 23:49:58,080 - JobSpy - INFO - LinkedIn search page: 3
# 2024-10-16 23:51:48,628 - JobSpy - INFO - Linkedin finished scraping

# %%
analyst_jobs.head()
# Out:
#                id       site  \
# 31  1009488161070  glassdoor
# 36  1009489283849  glassdoor
# 37  1009489321115  glassdoor
# 38  1009489033269  glassdoor
# 41  1009488884032  glassdoor
#
#                                               job_url job_url_direct  \
# 31  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 36  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 37  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 38  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 41  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
#
#                           title                   company  \
# 31                 Data Analyst               NHS England
# 36                 Data Analyst          ixceed solutions
# 37           Assessment Analyst                       AQA
# 38  Sustainability Data Analyst           DULWICH COLLEGE
# 41              HR Data Analyst  Colt Technology Services
#
#                                location job_type date_posted salary_source  \
# 31  Cambridge, East of England, England      NaN  2024-10-16   direct_data
# 36               Milton Keynes, England      NaN  2024-10-16           NaN
# 37                  Manchester, England      NaN  2024-10-16   direct_data
# 38                      London, England      NaN  2024-10-16   direct_data
# 41                      London, England      NaN  2024-10-16   direct_data
#
#     ...                                        company_url  \
# 31  ...  https://www.glassdoor.co.uk/Overview/W-EI_IE12...
# 36  ...  https://www.glassdoor.co.uk/Overview/W-EI_IE86...
# 37  ...  https://www.glassdoor.co.uk/Overview/W-EI_IE51...
# 38  ...  https://www.glassdoor.co.uk/Overview/W-EI_IE70...
# 41  ...  https://www.glassdoor.co.uk/Overview/W-EI_IE66...
#
#     company_url_direct  company_addresses company_num_employees  \
# 31                 NaN                NaN                   NaN
# 36                 NaN                NaN                   NaN
# 37                 NaN                NaN                   NaN
# 38                 NaN                NaN                   NaN
# 41                 NaN                NaN                   NaN
#
#    company_revenue company_description  \
# 31             NaN                 NaN
# 36             NaN                 NaN
# 37             NaN                 NaN
# 38             NaN                 NaN
# 41             NaN                 NaN
#
#                                        logo_photo_url banner_photo_url  \
# 31  https://media.glassdoor.com/sql/12873/uk-natio...              NaN
# 36  https://media.glassdoor.com/sql/864261/ixceed-...              NaN
# 37  https://media.glassdoor.com/sql/516520/aqa-squ...              NaN
# 38  https://media.glassdoor.com/sql/709474/dulwich...              NaN
# 41  https://media.glassdoor.com/sql/6684/colt-tech...              NaN
#
#    ceo_name ceo_photo_url
# 31      NaN           NaN
# 36      NaN           NaN
# 37      NaN           NaN
# 38      NaN           NaN
# 41      NaN           NaN
#
# [5 rows x 31 columns]

# %%
de_jobs = scrape_jobs(
    site_name=["indeed","linkedin","glassdoor"],
    search_term="data engineer",
    location="United Kingdom",
    results_wanted=30,
    hours_old=72, # (only Linkedin/Indeed is hour specific, others round up to days old)
    country_indeed="United Kingdom",  # only needed for indeed / glassdoor
    linkedin_fetch_description=True)
# Out:
# 2024-10-16 23:51:48,935 - JobSpy - INFO - Indeed search page: 1
# 2024-10-16 23:51:48,937 - JobSpy - INFO - LinkedIn search page: 1
# 2024-10-16 23:51:49,672 - JobSpy - INFO - Indeed finished scraping
# 2024-10-16 23:51:49,857 - JobSpy - INFO - Glassdoor search page: 1
# 2024-10-16 23:51:50,876 - JobSpy - INFO - Glassdoor finished scraping
# 2024-10-16 23:53:27,114 - JobSpy - INFO - LinkedIn search page: 2
# 2024-10-16 23:54:31,155 - JobSpy - INFO - LinkedIn search page: 3
# 2024-10-16 23:55:52,088 - JobSpy - INFO - Linkedin finished scraping

# %%
de_jobs.head()
# Out:
#                id       site  \
# 33  1009489697620  glassdoor
# 35  1009489697616  glassdoor
# 36  1009489267707  glassdoor
# 38  1009488188490  glassdoor
# 40  1009488981877  glassdoor
#
#                                               job_url job_url_direct  \
# 33  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 35  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 36  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 38  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
# 40  https://www.glassdoor.co.uk/job-listing/j?jl=1...            NaN
#
#                                                 title           company  \
# 33                     R&D Software and Data Engineer          Barclays
# 35              Senior R&D Software and Data Engineer          Barclays
# 36                                      Data Engineer            Beyond
# 38  Data Centre & Field Operations Associate Engineer               Sky
# 40                      Data Engineer (Elasticsearch)  ixceed solutions
#
#                 location job_type date_posted salary_source  ...  \
# 33    Knutsford, England      NaN  2024-10-16   direct_data  ...
# 35  Northampton, England      NaN  2024-10-16   direct_data  ...
# 36       London, England      NaN  2024-10-16   direct_data  ...
# 38       London, England      NaN  2024-10-16   direct_data  ...
# 40   Birmingham, England      NaN  2024-10-16           NaN  ...
#
#                                           company_url  company_url_direct  \
# 33  https://www.glassdoor.co.uk/Overview/W-EI_IE34...                 NaN
# 35  https://www.glassdoor.co.uk/Overview/W-EI_IE34...                 NaN
# 36                                                NaN                 NaN
# 38  https://www.glassdoor.co.uk/Overview/W-EI_IE39...                 NaN
# 40  https://www.glassdoor.co.uk/Overview/W-EI_IE86...                 NaN
#
#     company_addresses company_num_employees company_revenue  \
# 33                NaN                   NaN             NaN
# 35                NaN                   NaN             NaN
# 36                NaN                   NaN             NaN
# 38                NaN                   NaN             NaN
# 40                NaN                   NaN             NaN
#
#    company_description                                     logo_photo_url  \
# 33                 NaN  https://media.glassdoor.com/sql/3456/barclays-...
# 35                 NaN  https://media.glassdoor.com/sql/3456/barclays-...
# 36                 NaN                                                NaN
# 38                 NaN  https://media.glassdoor.com/sql/3903/sky-squar...
# 40                 NaN  https://media.glassdoor.com/sql/864261/ixceed-...
#
#    banner_photo_url ceo_name ceo_photo_url
# 33              NaN      NaN           NaN
# 35              NaN      NaN           NaN
# 36              NaN      NaN           NaN
# 38              NaN      NaN           NaN
# 40              NaN      NaN           NaN
#
# [5 rows x 31 columns]

# %%
con = duckdb.connect(database = "jobinfo.db")
con.execute("INSERT INTO jobinfo SELECT * FROM analyst_jobs UNION SELECT * FROM de_jobs")
